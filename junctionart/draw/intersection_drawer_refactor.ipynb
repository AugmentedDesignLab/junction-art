# %%
import os, sys
currentFolder = os.path.abspath('')
try:
    sys.path.remove(str(currentFolder))
except ValueError: # Already removed
    pass

projectFolder = 'C:/Users/abjaw/Documents/GitHub/junction-art'
# sys.path.append(str(projectFolder))
os.chdir(projectFolder)
print( f"current working dir{os.getcwd()}")
# Out:
# current working dirC:\Users\abjaw\Documents\GitHub\junction-art

# %%
from junctions.JunctionBuilderFromPointsAndHeading import JunctionBuilderFromPointsAndHeading
# from junctionart.draw.StraightRoadPolygon import StraightRoadPolygon
# from junctionart.draw.ParamPolyRoadPolygon import ParampolyRoadPolygon
from junctionart.draw.IntersectionDrawer import IntersectionDrawer
import math
import matplotlib.pyplot as plt

from shapely.geometry import Polygon

# %%
junctionBuilder = JunctionBuilderFromPointsAndHeading()
roadDefinition1 = [
            {'x':  -10, 'y': 0, 'heading': math.radians(180), 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
            {'x':   0, 'y': 10, 'heading': math.radians(90),  'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
            {'x':  10, 'y':  0, 'heading': math.radians(0), 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
            # {'x': -40, 'y': -30, 'heading': -2,  'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None},
        ]
_intersection = junctionBuilder.createIntersectionFromPointsWithRoadDefinition(odrID=0,
                                                                            firstRoadId=0,
                                                                            roadDefinition=roadDefinition1,
                                                                            straightRoadLen=40,
                                                                            getAsOdr=False)


intersection_drawer = IntersectionDrawer(_intersection, step = 0.1)
intersection_drawer.draw_polygon_image_arr(include_u_turn=False)
intersection_drawer.draw_intersection_and_conflict_area_fill(include_u_turn=False)
intersection_drawer.get_area_values(include_u_turn=False)
# Out:
# [{'x': -10, 'y': 0, 'heading': 0.0, 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None}, {'x': 0, 'y': 10, 'heading': -1.5707963267948966, 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None}, {'x': 10, 'y': 0, 'heading': -3.141592653589793, 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None}]
# {'IntersectionArea': 188.4819586282704, 'ConflictArea': 114.89495068033072}

# %%
# intersection_drawer.intersection_polygon.area_geometry.interior_and_exterior_area_of_intersection()

# %%
# intersection_drawer.draw_intersection(color='b', include_u_turn=True)

# %%
# junctionBuilder = JunctionBuilderFromPointsAndHeading()
roadDefinition2 = [
            {'x':  -10, 'y': 0, 'heading': math.radians(170), 'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None},
            {'x':   0, 'y': 10, 'heading': math.radians(90),  'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
            {'x':  10, 'y':  0, 'heading': math.radians(0), 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
            # {'x': -40, 'y': -30, 'heading': -2,  'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None},
        ]
_intersection = junctionBuilder.createIntersectionFromPointsWithRoadDefinition(odrID=0,
                                                                            firstRoadId=0,
                                                                            roadDefinition=roadDefinition2,
                                                                            straightRoadLen=40,
                                                                            getAsOdr=False)


intersection_drawer = IntersectionDrawer(_intersection, step = 0.1)
intersection_drawer.draw_polygon_image_arr(include_u_turn=False)
intersection_drawer.draw_intersection_and_conflict_area_fill(include_u_turn=False)
intersection_drawer.get_area_values(include_u_turn=False)
# Out:
# [{'x': -10, 'y': 0, 'heading': 0.0, 'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None}, {'x': 0, 'y': 10, 'heading': -1.3962634015954638, 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None}, {'x': 10, 'y': 0, 'heading': -2.9670597283903604, 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None}]
# {'IntersectionArea': 224.61374565940386, 'ConflictArea': 129.25564939355812}

# %%
# # junctionBuilder = JunctionBuilderFromPointsAndHeading()
# roadDefinition5 = [
#             {'x':  -10, 'y': 0, 'heading': math.radians(180), 'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None},
#             {'x':   0, 'y': 10, 'heading': math.radians(45),  'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
#             {'x':  10, 'y':  0, 'heading': math.radians(0), 'leftLane': 1, 'rightLane': 1, 'medianType': None, 'skipEndpoint': None},
#             # {'x': -40, 'y': -30, 'heading': math.radians(-90),  'leftLane': 2, 'rightLane': 2, 'medianType': None, 'skipEndpoint': None},
#         ]
# _intersection = junctionBuilder.createIntersectionFromPointsWithRoadDefinition(odrID=0,
#                                                                             firstRoadId=0,
#                                                                             roadDefinition=roadDefinition5,
#                                                                             straightRoadLen=40,
#                                                                             getAsOdr=False)


# intersection_drawer = IntersectionDrawer(_intersection)

# intersection_drawer.draw_polygon_image_arr()

# %%
# intersection_drawer.draw_road_overlap_area()

# %%
# import matplotlib.pyplot as plt
# for polygon in polygon_list:
#     print(polygon.type)
#     x, y = polygon.exterior.xy
#     plt.plot(x, y, color = 'r')

# %%
# import matplotlib.pyplot as plt
# for i in range(len(polygon_list)):
#     for polygon in polygon_list[i]:
#         x, y = polygon.exterior.xy
#         plt.plot(x, y, color = 'r')
# plt.show()

# %%
# print(road.lanes.lanesections[0].centerlane)
# print(len(road.lanes.lanesections[0].leftlanes))
# print(len(road.lanes.lanesections[0].rightlanes))

# %%
import numpy as np
import matplotlib.pyplot as plt


arr = '1604.2153052355699856 294.6438516037940190, 1604.8377043811299245 296.0369050221527232, 1606.0002439822671931 296.8424557999927629, 1607.5899815609159305 297.1330769407987873, 1609.4939746390111850 296.9813414480553320, 1611.5992807384868684 296.4598223252469325, 1613.7929573812778017 295.6410925758582948, 1615.9620620893181240 294.5977252033738978, 1617.9936523845428837 293.4022932112783906, 1619.7747857888862200 292.1273696030563087, 1621.1925198242824990 290.8455273821923583, 1619.0178073037523063 288.7789782167841963, 1617.9043508038598702 289.7818477065927141, 1616.3624561518993232 290.8845166424364947, 1614.5490622877716760 291.9513254677274290, 1612.6109930071129384 292.8837459857094814, 1610.6989007753998067 293.5981242415785459, 1608.9844694255918967 294.0249239475153900, 1607.6873663744781879 294.1346579910708670, 1607.0762481426431805 294.0420602838462401, 1607.1368594645864505 294.1097605277735738, 1607.1658189146567111 294.1012015973240636, 1604.2153052355699856 294.6438516037940190'

x = []
y = []
points = arr.split(',')
for p in points:
    temp = p.split()
    x.append(np.float64(temp[0]))
    y.append(np.float64(temp[1]))

plt.plot(x, y)
plt.show()
