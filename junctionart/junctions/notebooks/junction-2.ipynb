# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import junctionart.extensions, junctions
from junctionart.extensions.signalManager import SignalManager
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
# %matplotlib inline
# Out:
# current working dirC:\Users\ishaa\source\repos\junction-art

# %%
roadBuilder = junctions.RoadBuilder()
#1. create two arbitrary roads

roads = []
roads.append(pyodrx.create_straight_road(0, 20))
# roads.append(pyodrx.create_straight_road(1, junction=1))
# roads.append(pyodrx.create_cloth_arc_cloth(.05, arc_angle=(np.pi - np.pi/4), cloth_angle=np.pi/8, r_id=1, junction = 1))
# roads.append(roadBuilder.createSimpleCurve(1, np.pi/4, True, curvature = 0.9))
# roads.append(roadBuilder.createSimpleCurveWithLongArc(1, -np.pi/16, True, curvature = 0.5))
roads.append(roadBuilder.createS(1, -np.pi/20, True, curvature = 0.1))
roads.append(pyodrx.create_straight_road(2))

roads[0].add_successor(pyodrx.ElementType.junction,1)

roads[1].add_predecessor(pyodrx.ElementType.road,0,pyodrx.ContactPoint.end)
roads[1].add_successor(pyodrx.ElementType.road,2,pyodrx.ContactPoint.start)

roads[2].add_predecessor(pyodrx.ElementType.junction,1)

#2. create a connection road



# 3. create junction
junction = pyodrx.Junction('test',1)

con1 = pyodrx.Connection(0,1,pyodrx.ContactPoint.start)
con1.add_lanelink(-1,-1)

junction.add_connection(con1)


#4. make xord, add roads, add junctions, adjust

# create the opendrive
odr = pyodrx.OpenDrive('myroad')
for r in roads:
    odr.add_road(r)

# odr.add_junction(junction)
odr.adjust_roads_and_lanes()

# instantiate signalManager object and add all required signals elements
signalManager = SignalManager()
for index in odr.roads:
    signalManager.addSignal(odr.roads[str(index)])
    odr.roads[str(index)].signals = signalManager.signalsList[int(index)] #copy current signals object to signals object within roads object

# Check outputs in the Opendrive xml.
# pyodrx.prettyprint(signalManager.signals.get_element())
pyodrx.prettyprint(odr.get_element())

#extensions.view_road(odr,os.path.join('..','C:\\Users\\ishaa\\Downloads\\roadGen\\esmini-master'))
# Out:
# start points starting
# <?xml version="1.0" ?>
# <OpenDRIVE>
# 	<header name="myroad" revMajor="1" revMinor="5" date="2020-12-02 11:07:22.059688" north="0.0" south="0.0" east="0.0" west="0.0"/>
# 	<road id="0" junction="-1" length="20">
# 		<link>
# 			<successor elementType="junction" elementId="1"/>
# 		</link>
# 		<planView>
# 			<geometry s="0" x="0" y="0" hdg="0" length="20">
# 				<line/>
# 			</geometry>
# 		</planView>
# 		<lanes>
# 			<laneSection s="0">
# 				<left>
# 					<lane id="1" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</left>
# 				<center>
# 					<lane id="0" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</center>
# 				<right>
# 					<lane id="-1" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</right>
# 			</laneSection>
# 		</lanes>
# 		<signals>
# 			<signal s="20" t="3" dynamic="no" orientation="+"/>
# 		</signals>
# 	</road>
# 	<road id="1" junction="1" length="46.18141200776996">
# 		<link>
# 			<predecessor elementType="road" elementId="0" contactPoint="end"/>
# 			<successor elementType="road" elementId="2" contactPoint="start"/>
# 		</link>
# 		<planView>
# 			<geometry s="0" x="20.0" y="0.0" hdg="0" length="3.2986722862692828">
# 				<spiral curvStart="1e-09" curvEnd="0.1"/>
# 			</geometry>
# 			<geometry s="3.2986722862692828" x="23.289710169784943" y="0.1810019043492141" hdg="0.1649336159628003" length="29.688050576423546">
# 				<arc curvature="0.1"/>
# 			</geometry>
# 			<geometry s="32.98672286269283" x="21.726380680221038" y="20.04498604998361" hdg="3.133738673605155" length="9.896016858807847">
# 				<arc curvature="-0.15000000000000002"/>
# 			</geometry>
# 			<geometry s="42.88273972150068" x="15.132624451125729" y="26.188386451887922" hdg="1.6493361447839776" length="3.2986722862692828">
# 				<spiral curvStart="-0.1" curvEnd="1e-09"/>
# 			</geometry>
# 		</planView>
# 		<lanes>
# 			<laneSection s="0">
# 				<left>
# 					<lane id="1" type="driving" level="false">
# 						<link>
# 							<predecessor id="1"/>
# 							<successor id="1"/>
# 						</link>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</left>
# 				<center>
# 					<lane id="0" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</center>
# 				<right>
# 					<lane id="-1" type="driving" level="false">
# 						<link>
# 							<predecessor id="-1"/>
# 							<successor id="-1"/>
# 						</link>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</right>
# 			</laneSection>
# 		</lanes>
# 		<signals>
# 			<signal s="46.18141200776996" t="3" dynamic="no" orientation="+"/>
# 		</signals>
# 	</road>
# 	<road id="2" junction="-1" length="100">
# 		<link>
# 			<predecessor elementType="junction" elementId="1"/>
# 		</link>
# 		<planView>
# 			<geometry s="0" x="15.236154747195704" y="29.4814452380743" hdg="1.4844025321198495" length="100">
# 				<line/>
# 			</geometry>
# 		</planView>
# 		<lanes>
# 			<laneSection s="0">
# 				<left>
# 					<lane id="1" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</left>
# 				<center>
# 					<lane id="0" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</center>
# 				<right>
# 					<lane id="-1" type="driving" level="false">
# 						<link/>
# 						<width a="3" b="0" c="0" d="0" sOffset="0"/>
# 						<roadMark sOffset="0" type="solid" weight="standard" color="standard" width="0.2" laneChange="none" height="0.02">
# 							<type name="solid" width="0.2">
# 								<line length="0" space="0" tOffset="0" width="0.2" sOffset="0" rule="no passing"/>
# 							</type>
# 						</roadMark>
# 					</lane>
# 				</right>
# 			</laneSection>
# 		</lanes>
# 		<signals>
# 			<signal s="100" t="3" dynamic="no" orientation="+"/>
# 		</signals>
# 	</road>
# </OpenDRIVE>

# %%
roads[1].curveType
# Out:
# <StandardCurveTypes.S: 3>
