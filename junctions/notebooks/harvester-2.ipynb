# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import extensions
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# current working dirF:\myProjects\av\junction-art
# Using matplotlib backend: Qt5Agg

# %%
import junctions
import os

# %%
outputDir= os.path.join(os.getcwd(), 'output')

# %%
harvester = junctions.JunctionHarvester(outputDir=outputDir, outputPrefix='', lastId=0, minAngle = np.pi / 10, maxAngle = np.pi)

# %%
harvester.harvest2ways2Lanes()
# Out:
# randomSome2ways2Lanes: creating 6 for angle: 18.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 27.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 36.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 45.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 54.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 63.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 72.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 81.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 90.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 99.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 108.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 117.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 126.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 135.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 144.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 153.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# randomSome2ways2Lanes: creating 6 for angle: 162.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# created 102 roads

# %%
for angle in [18, 45, 72, 153]:
    for i in range(6):
        xodrPath = os.path.join(outputDir,  f"road2lane2angle{angle}no{i}.xodr")
        # print(xodrPath)
        extensions.viewRoadFromFile(xodrPath, 'F:\\myProjects\\av\\esmini')
# Out:
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no0.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no1.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no2.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no3.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no4.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no5.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no0.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no1.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no2.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no3.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no4.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle27no5.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no0.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no1.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no2.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no3.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no4.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle45no5.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no0.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no1.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no2.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no3.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no4.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle72no5.xodr
# opening matplot lib

# %%
np.random.choice(5)
# Out:
# 0
