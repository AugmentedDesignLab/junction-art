# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import extensions
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# current working dirF:\myProjects\av\junction-art
# Using matplotlib backend: Qt5Agg

# %%
import junctions
import os

# %%
outputDir= os.path.join(os.getcwd(), 'output')

# %%
harvester = junctions.JunctionHarvester(outputDir=outputDir, outputPrefix='', lastId=0, minAngle = np.pi / 10, maxAngle = np.pi)

# %%
harvester.harvest2ways2Lanes(maxTries = 1000)
# Out:
# randomSome2ways2Lanes: creating 56 for angle: 18.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 27.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 36.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 45.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 54.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 63.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 72.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 81.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 90.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# ...
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 162.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# randomSome2ways2Lanes: creating 56 for angle: 171.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# created 1008 roads

# %%
for angle in [18, 45, 153]:
    for i in range(6):
        xodrPath = os.path.join(outputDir,  f"road2lane2angle{angle}no{i}.xodr")
        # print(xodrPath)
        extensions.viewRoadFromFile(xodrPath, 'F:\\myProjects\\av\\esmini')
# Out:
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no0.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no1.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no2.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no3.xodr
# opening matplot lib
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle18no4.xodr
# opening matplot lib
