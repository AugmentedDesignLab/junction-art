# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import extensions
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# current working dirF:\myProjects\av\junction-art

# %%
import junctions
import os

# %%
outputDir= os.path.join(os.getcwd(), 'output')

# %%
harvester = junctions.JunctionHarvester(outputDir=outputDir, outputPrefix='', lastId=0, minAngle = np.pi / 10, maxAngle = np.pi)

# %%
harvester.harvest2ways2Lanes()
# Out:
# randomSome2ways2Lanes: creating 6 for angle: 18.0
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# starting adjustment. May freeze!!!!!!!!!!!!!
# analizing roads 0 1
# analizing roads 0 2
# analizing roads 1 2
# adjustment done, didn't freeze!!!!!!!!!
# ...

# %%
xodrPath = os.path.join(outputDir,  'road2lane2angle162no5.xodr')
print(xodrPath)
# xodrPath = "F:\\myProjects\\av\\esmini\\resources\\xodr\\pythonroad2.xodr"
extensions.viewRoadFromFile(xodrPath, 'F:\\myProjects\\av\\esmini')
# Out:
# F:\myProjects\av\junction-art\output\road2lane2angle99no0.xodr
# plotting xord: F:\myProjects\av\junction-art\output\road2lane2angle99no0.xodr
# opening matplot lib
