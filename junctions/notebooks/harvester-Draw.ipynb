# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import extensions
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# current working dirF:\myProjects\av\junction-art
# Using matplotlib backend: Qt5Agg

# %%
import junctions
import os

# %%
outputDir= os.path.join(os.getcwd(), 'output')
lastId = 1000
harvester = junctions.JunctionHarvester(outputDir=outputDir, 
                                        outputPrefix='paint_', 
                                        lastId=lastId)

# %%
harvester.harvestByPainting2L(6, 10)
# Out:
# availableAngle 324.0, number of roads: 0.5
# Curvature for angle 72.0 is 0.2
# availableAngle 252.0, number of roads: 1.5
# Curvature for angle 162.0 is 0.03
# connecting roads 0 1
# connecting roads 2 3
# number of roads created 5
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\paint_Draw_Rmax3_L2_1000.xodr
# saving image to F:\myProjects\av\junction-art\output\paint_Draw_Rmax3_L2_1000.xodr-image.png
# availableAngle 324.0, number of roads: 0.5
# Curvature for angle 36.0 is 0.6
# availableAngle 288.0, number of roads: 1.5
# Curvature for angle 162.0 is 0.03
# connecting roads 0 1
# connecting roads 2 3
# number of roads created 5
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\paint_Draw_Rmax3_L2_1001.xodr
# ...
