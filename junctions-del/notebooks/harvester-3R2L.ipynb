# %%
exec(open("init_notebook.py").read())
import pyodrx 
import numpy as np
import extensions
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# current working dirF:\myProjects\av\junction-art
# Using matplotlib backend: Qt5Agg

# %%
import junctions
import os

# %%
outputDir= os.path.join(os.getcwd(), 'output')
lastId = 0
harvester = junctions.JunctionHarvester(outputDir=outputDir, 
                                        outputPrefix='merged_', 
                                        lastId=lastId)

# %%
harvester.harvest3WayJunctionsFrom2Ways('F:\\myProjects\\av\\junction-art\\output\\harvested2R2LOrds.dill')
# Out:
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_1.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_1.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_2.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_2.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_3.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_3.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_4.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_4.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_5.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_5.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_6.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_6.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_7.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_7.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_8.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_8.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_9.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_9.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_10.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_10.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_11.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_11.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_12.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_12.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_13.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_13.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_14.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_14.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_15.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_15.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_16.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_16.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_17.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_17.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_18.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_18.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_19.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_19.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_20.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_20.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_21.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_21.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_22.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_22.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_23.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_23.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_24.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_24.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_25.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_25.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_26.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_26.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_27.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_27.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_28.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_28.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_29.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_29.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_30.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_30.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_31.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_31.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_32.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_32.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_33.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_33.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_34.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_34.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_35.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_35.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_36.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_36.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_37.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_37.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_38.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_38.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_39.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_39.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_40.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_40.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_41.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_41.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_42.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_42.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_43.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_43.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_44.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_44.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_45.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_45.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_46.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_46.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_47.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_47.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_48.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_48.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_49.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_49.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_50.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_50.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_51.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_51.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_52.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_52.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_53.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_53.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_54.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_54.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_55.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_55.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_56.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_56.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_57.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_57.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_58.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_58.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_59.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_59.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_60.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_60.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_61.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_61.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_62.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_62.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_63.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_63.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_64.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_64.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_65.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_65.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_66.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_66.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_67.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_67.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_68.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_68.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_69.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_69.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_70.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_70.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_71.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_71.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_72.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_72.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_73.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_73.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_74.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_74.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_75.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_75.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_76.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_76.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_77.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_77.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_78.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_78.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_79.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_79.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_80.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_80.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_81.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_81.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_82.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_82.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_83.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_83.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_84.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_84.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_85.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_85.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_86.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_86.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_87.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_87.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_88.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_88.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_89.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_89.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_90.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_90.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_91.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_91.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_92.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_92.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_93.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_93.xodr-image.png
# starting adjustment. May freeze!!!!!!!!!!!!!
# start points starting
# F:\myProjects\av\esmini\bin\odrplot.exe F:\myProjects\av\junction-art\output\merged_3R_2L_94.xodr
# saving image to F:\myProjects\av\junction-art\output\merged_3R_2L_94.xodr-image.png
# Odr objects saved to F:\myProjects\av\junction-art\output\merged__harvested3R2LOrds.dill

# %%
extensions.viewRoadFromXODRFile('F:\\myProjects\\av\\junction-art\\output\\merged_3R_2L_13.xodr', "f:\\myProjects\\av\\esmini")
# Out:
# f:\myProjects\av\esmini\bin\odrplot.exe F:/myProjects/av/junction-art/output/merged_3R_2L_13.xodr
